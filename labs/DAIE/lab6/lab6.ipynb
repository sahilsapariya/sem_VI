# %% [markdown]
# # Experiment 6
#
# __AIM:__ To perform Decision-tree classification using Sci-kit learn package in Python

# %%
import pandas as pd
import numpy as np
import sklearn.datasets as data
from sklearn.model_selection import train_test_splits

# %%
iris = data.load_iris()
iris_data = iris.data
iris_target = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_data, iris_target, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
dct = DecisionTreeClassifier()

# %%
dct.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_hat = dct.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.9333333333333333

# %%
confusion_matrix(y_test, y_hat)
# Out:
# array([[ 9,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  1, 10]])

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
features = iris.feature_names
classes = list(iris.target_names)

# %%
plot_tree(
    dct,
    feature_names=features,
    class_names=classes,
    rounded=True,
    filled=True,
    proportion=True
)
# Out:
# [Text(0.4, 0.9166666666666666, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 100.0%\nvalue = [0.342, 0.333, 0.325]\nclass = setosa'),
#  Text(0.3, 0.75, 'gini = 0.0\nsamples = 34.2%\nvalue = [1.0, 0.0, 0.0]\nclass = setosa'),
#  Text(0.5, 0.75, 'petal length (cm) <= 4.85\ngini = 0.5\nsamples = 65.8%\nvalue = [0.0, 0.506, 0.494]\nclass = versicolor'),
#  Text(0.2, 0.5833333333333334, 'petal width (cm) <= 1.7\ngini = 0.051\nsamples = 31.7%\nvalue = [0.0, 0.974, 0.026]\nclass = versicolor'),
#  Text(0.1, 0.4166666666666667, 'gini = 0.0\nsamples = 30.0%\nvalue = [0.0, 1.0, 0.0]\nclass = versicolor'),
#  Text(0.3, 0.4166666666666667, 'sepal width (cm) <= 3.0\ngini = 0.5\nsamples = 1.7%\nvalue = [0.0, 0.5, 0.5]\nclass = versicolor'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 0.8%\nvalue = [0.0, 0.0, 1.0]\nclass = virginica'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 0.8%\nvalue = [0.0, 1.0, 0.0]\nclass = versicolor'),
#  Text(0.8, 0.5833333333333334, 'petal width (cm) <= 1.75\ngini = 0.136\nsamples = 34.2%\nvalue = [0.0, 0.073, 0.927]\nclass = virginica'),
#  Text(0.7, 0.4166666666666667, 'petal length (cm) <= 4.95\ngini = 0.5\nsamples = 5.0%\nvalue = [0.0, 0.5, 0.5]\nclass = versicolor'),
#  Text(0.6, 0.25, 'gini = 0.0\nsamples = 1.7%\nvalue = [0.0, 1.0, 0.0]\nclass = versicolor'),
#  Text(0.8, 0.25, 'sepal length (cm) <= 6.5\ngini = 0.375\nsamples = 3.3%\nvalue = [0.0, 0.25, 0.75]\nclass = virginica'),
#  Text(0.7, 0.08333333333333333, 'gini = 0.0\nsamples = 2.5%\nvalue = [0.0, 0.0, 1.0]\nclass = virginica'),
#  Text(0.9, 0.08333333333333333, 'gini = 0.0\nsamples = 0.8%\nvalue = [0.0, 1.0, 0.0]\nclass = versicolor'),
#  Text(0.9, 0.4166666666666667, 'gini = 0.0\nsamples = 29.2%\nvalue = [0.0, 0.0, 1.0]\nclass = virginica')]

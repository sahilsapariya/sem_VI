# %% [markdown]
# # Experiment 5
#
# __AIM:__ To perform Regression Analysis using Sci-Kit learn package in Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
from sklearn.datasets import load_iris 
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
iris = load_iris()
# iris_data = iris.data
iris_data = iris.data
iris_target = iris.target

# %%
iris_df = pd.DataFrame(data=iris_data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_data, iris.target, test_size=0.2, random_state=42)

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = linear_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, prediction)
mse
# Out:
# 0.19795466813955878

# %%
linear_model.score(X_test, y_test)
# Out:
# 0.9468960016420045

# %%
# Set the style of seaborn for better visualization
sns.set(style="whitegrid")

# Create a pair plot using seaborn
sns.pairplot(iris_df, hue="target", markers=["o", "s", "D"])

# Show the plot
plt.show()
# Out:
# /Users/sahilsapariya/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Plot the actual data points
plt.scatter(X_test, y_test, color='black', label='Actual Data')

# Plot the linear regression line
plt.plot(X_test, predictions, color='blue', linewidth=3, label='Linear Regression Line')

# Add labels and title
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Target')
plt.title('Linear Regression on Iris Dataset')

# Add a legend
plt.legend()

# Show the plot
plt.show()
